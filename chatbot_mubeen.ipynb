# %% [markdown]
# <p align="center">
#   <img src="https://i.imgur.com/embH4HC.png" width="800">
# </p>

# %%
faq_data = {
    # القسم 1: الأسئلة عن التطبيق
    "ما هو هذا التطبيق؟": "هذا تطبيق ذكي يساعد الركاب من الصم والبكم في التواصل أثناء الرحلات الجوية باستخدام الذكاء الاصطناعي.",
    "كيف يساعدني التطبيق؟": "يساعدك من خلال تحويل الإشارات إلى نصوص أو صوت، والعكس، لتتواصل مع طاقم الطائرة بسهولة.",
    "هل يمكن استخدام التطبيق بدون إنترنت؟": "حالياً يتطلب اتصالًا بالإنترنت، ولكن نعمل على دعم الوضع دون إنترنت مستقبلًا.",
    "أين يمكنني تحميل التطبيق؟": " متاحا في متاجرالتطبيقات وسيكون على شاشات الطائرة مستقبلًا.",
    "هل يمكن استخدام التطبيق بعد الرحلة؟": "نعم، يعمل من بداية الرحلة في المطار وحتى الوصول للوجهة، وقد يتوسع مستقبلاً للاستخدام خارج الرحلة.",

    # القسم 2: الأسئلة عن الرحلة
    "ما رقم الرحلة؟": "يمكنك العثور على رقم الرحلة في تذكرة الحجز الخاصة بك أو على بطاقة صعود الطائرة.",
    "ما وقت الإقلاع؟": "يرجى التحقق من شاشة الرحلات أو تطبيق شركة الطيران لموعد الإقلاع.",
    "ما وقت الوصول؟": "وقت الوصول يعتمد على خط سير الرحلة، ويمكنك متابعته من خلال التطبيق.",
    "ما مدة الرحلة؟": "مدة الرحلة تختلف حسب الوجهة. يمكنك التحقق من ذلك في تفاصيل الرحلة.",
    "كم باقي على موعد الرحلة؟": "الرجاء إدخال رقم الرحلة وسأزودك بالوقت المتبقي.",
    "ما هو رقم بوابتي؟": "الرجاء إدخال رقم رحلتك لأتمكن من تحديد البوابة.",
    "أين مقعدي؟": "موقع مقعدك موجود في بطاقة صعود الطائرة، مثل 12A أو 15B.",
    "هل أستطيع تغيير مقعدي؟": "يمكنك طلب تغيير المقعد من خلال الطاقم إذا كانت هناك مقاعد شاغرة.",
    "ما رقم رحلتي؟": "يمكنك إيجاد رقم الرحلة على تذكرتك الإلكترونية.",

    # القسم 3: الخدمات المتوفرة على الطائرة
    "ما الخدمات المتوفرة؟": "تشمل الخدمات الترفيه، الوجبات، الإنترنت .",
    "هل يوجد إنترنت في الطائرة؟": "نعم، بعض الطائرات تدعم خدمة الإنترنت، تحقق من خياراتك في الشاشة.",
    "ما الخدمات الترفيهية المتوفرة؟": "أفلام، ألعاب، موسيقى، وكتب إلكترونية متوفرة على شاشتك.",
    "كيف أطلب وجبة؟": "استخدم التطبيق لاختيار وجبتك أو اطلب من الطاقم مباشرة.",

    # القسم 4: التواصل والطوارئ
    "كيف أبلغ عن حالة طارئة؟": "اضغط على زر الطوارئ في التطبيق وسيصل تنبيه فوري للطاقم.",
    "أحتاج مساعدة، ماذا أفعل؟": "يمكنك التواصل عبر التطبيق أو استخدام الكاميرا لتوضيح حاجتك.",
    "هل يوجد مترجم لغة إشارة؟": "نعم، التطبيق يترجم لغة الإشارة إلى نص وصوت والعكس.",

    # القسم 5: التحويلات والذكاء الاصطناعي
    "هل يمكن للتطبيق قراءة لغة الإشارة؟": "نعم، التطبيق يستخدم الكاميرا وتقنيات الرؤية الحاسوبية للتعرف على لغة الإشارة.",
    "هل يمكنني التحدث والتطبيق يكتب؟": "نعم، التطبيق يدعم تحويل الصوت إلى نص.",
    "هل يمكن تحويل النص إلى صوت؟"
    "تابة والموظف يسمع؟": "نعم، التطبيق يحول النص الذي تكتبه إلى صوت يمكن للمضيفين سماعه.",
}

# %%
def chatbot():
    print("✈️ مرحباً بك في المساعد الذكي للمسافرين من ذوي الإعاقة السمعية والنطقية.")
    print("🔶 اكتب 'ابدأ' لبدء المحادثة أو 'خروج' لإنهائها.")

    while True:
        start = input("🟨: ").strip().lower()
        if start == "ابدأ":
            print("✅ بدأنا! اسأل ما تريد 🌟")
            break
        elif start in ['خروج', 'انهاء', 'exit', 'quit']:
            print("📴 تم إنهاء المحادثة. نتمنى لك رحلة سعيدة!")
            return
        else:
            print("❗ يرجى كتابة 'ابدأ' أو 'خروج'.")

    while True:
        question = input("🟨: ").strip()
        if question.lower() in ['خروج', 'انهاء', 'exit', 'quit']:
            print("📴 تم إنهاء المحادثة. شكراً لتواصلك معنا! ✋")
            break
        response = faq_data.get(question, "🤔 عذرًا، لم أفهم سؤالك. حاول بصيغة مختلفة أو اسأل سؤالاً آخر.")
        print("🤖 الإجابة:", response)


chatbot()
# Out:
# ✈️ مرحباً بك في المساعد الذكي للمسافرين من ذوي الإعاقة السمعية والنطقية.
# 🔶 اكتب 'ابدأ' لبدء المحادثة أو 'خروج' لإنهائها.
# 🟨: ابدأ
# ✅ بدأنا! اسأل ما تريد 🌟
# 🟨: ما هو هذا التطبيق؟
# 🤖 الإجابة: هذا تطبيق ذكي يساعد الركاب من الصم والبكم في التواصل أثناء الرحلات الجوية باستخدام الذكاء الاصطناعي.
# 🟨: كيف أبلغ عن حالة طارئة؟
# 🤖 الإجابة: اضغط على زر الطوارئ في التطبيق وسيصل تنبيه فوري للطاقم.
# 🟨: خروج
# 📴 تم إنهاء المحادثة. شكراً لتواصلك معنا! ✋
